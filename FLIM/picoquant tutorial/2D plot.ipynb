# %%
import Picoquant_PL as pl

import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16904/1174526894.py in <module>
# ----> 1 import Picoquant_PL as pl
#       2
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ~\OneDrive - University of Cambridge\Documents\Mini 1\Microscope\confocal_analysis_Jupyter\Files from Alan\Picoquant_PL.py in <module>
# ----> 1 import phconvert as phc
#       2 import numpy as np
#       3 from numba import jit
#       4 import matplotlib.pyplot as plt
#       5 from matplotlib.patches import Rectangle
#
# ModuleNotFoundError: No module named 'phconvert'

# %%
data, tags = pl.import_convert('MAPbBr3_nodunkblow_crystal7_2P_0p5um_100xSWD_8MHz_1400au_800nm_50frames', detector = 1)
# Out:
#  - Loading 'MAPbBr3_nodunkblow_crystal7_2P_0p5um_100xSWD_8MHz_1400au_800nm_50frames.ptu' ...

# %%
plt.imshow(data.sum(2))

# %% [markdown]
# Data is 3D cube, index into cube along axis 2 (3rd axis)

# %% [markdown]
# The below will select all timesteps between 200 and 300 i.e. (200 - 299). The sum will add these up.

# %%
plt.imshow(data[..., 200:300].sum(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f0186c41e28> in <module>
# ----> 1 plt.imshow(data[..., 200:300].sum(2)) # The ellipsis ... means as many : as needed --> just a way of accessing the last column in an array
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Each timestep is 2.5e-11 s

# %%
tags['MeasDesc_Resolution']['value']
# Out:
# 2.50000003337858e-11

# %% [markdown]
# So 200 - 300 will be correspond to a snapshot of the image bewteen 5 ns and 7.5 ns taking the start of the measruemant to be zero time, not the maximum etc... See tcspc decay below area between black lines the start included but not the final value

# %%
plt.plot(data.sum((0, 1)))
plt.yscale('log')
plt.axvline(200, color='black')
plt.axvline(300, color='black')

# %%
plt.plot(data.sum((0, 1)))
plt.yscale('log')
plt.axvline(200, color='black')
plt.axvline(300, color='black')
plt.xlim(100, 400);
